# %% [markdown]
# # Cinema e film
# ### Analisi del rendimento
# ##### 1994 - 2018
# ***
# ### *Ilario De Francesch*

# %% [markdown]
# # Introduzione
#
# ### Perché i film?
#
# * Dataset interessante
# * Capire meglio il mondo che ci sta dietro
#
# ###
# ### Servono conoscenze pregresse?
#
# * Solo conoscere i numeri!

# %% [markdown]
# # Domande
#
# 1. Come è variato l'incasso del cinema e dei generi negli anni?
# 2. Produrre più film porta a un successo maggiore?
# 3. Esistono gruppi di generi che producono un profitto simile?
# 4. È possibile fare una predizione sul guadagno annuo del genere?
# 5. Qual è il genere i cui migliori film dell'anno hanno venduto più biglietti?

# %% [markdown]
# # Dataset
#
# ### Origine
# * Pubblico
# * Fonte: [Kaggle](https://www.kaggle.com/datasets/thedevastator/film-genre-statistics)
#
# ###
# ### Contenuto
# * Dati sui generi cinematografici
# * Numero di film usciti, guadagno generato, miglior film dell'anno

# %% [markdown]
# # Come è variato l'incasso del cinema e dei generi negli anni?

# %%
from IPython.display import Image
Image(filename = "figures/1_1.png")

# %% [markdown]
# ### Andando più a fondo...

# %%
Image(filename = "figures/1_2.png")

# %% [markdown]
# # Produrre più film porta a un successo maggiore?

# %%
Image(filename = "figures/2_1.png")

# %%
Image(filename = "figures/2_2.png")

# %%
Image(filename = "figures/2_3.png")

# %% [markdown]
# # Esistono gruppi di generi che producono un profitto simile?

# %%
Image(filename = "figures/3_1.png")

# %% [markdown]
# # È possibile fare una predizione sul guadagno annuo del genere?

# %%
Image(filename = "figures/4_1.png")

# %% [markdown]
# # Qual è il genere i cui migliori film dell'anno hanno venduto più biglietti?

# %%
Image(filename = "figures/5_1.png")

# %% [markdown]
# # Conclusioni
# ### Come è variato l'incasso del cinema e dei generi negli anni?
# Quello del cinema è aumentato. L'incasso dei vari generi invece dipende dal genere stesso.
# ### Produrre più film porta a un successo maggiore?
# Sembra esserci una correlazione ma, ancora, il tutto dipende dal genere.
# ### Esistono gruppi di generi che producono un profitto simile?
# Sì, se ne possono individuare due. Esistono però anche dei generi che non rientrano in questi gruppi.
# ### È possibile fare una predizione sul guadagno annuo del genere?
# Sì, ad esempio quella del genere 'Action' segue un andamento parabolico.
# ### Qual è il genere i cui migliori film dell'anno hanno venduto più biglietti?
# Il genere 'Adventure'.
